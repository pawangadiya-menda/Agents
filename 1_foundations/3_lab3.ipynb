# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value! This is the start of a lab that will last 2 days.
#
# And we're going to hand-build an Agent Loop without any Agent Framework..
#
# ### First, some prep
#
# In the folder `twin` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours! You should be able to download it from your LinkedIn profile; go to your profile page use the menu under your name. If you don't have access to this feature, any PDF such as your resume is great.
#
# I've also made a file called `summary.txt` in `twin` - please read it and update it to reflect you.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. If you're wondering how you would select packages for your own projects, please see Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> page.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr
import json

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("twin/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# 9701709381 (Home)
# pawangadiya@gmail.com
# www.linkedin.com/in/pawangadiya
# (LinkedIn)
# pawansaxblog.blogspot.com/
# (Blog)
# www.comakeit.com/ (Company)
# Top Skills
# Enterprise Software
# Agile Application Development
# Stakeholder Management
# Certifications
# Product Management Certification
# Program
# Product Management
# Honors-Awards
# Super-Duper Team Award
# Magic Cabinet Award
# Performance Award & Publication
# Under Company Newsletter
# Performance Award (iPad)
# Pawan Gadiya
# Senior Product manager | Enterprise B2B SaaS Leader | 0→1
# Product Builder | AI-Native Product Strategist | Product Growth,
# Platform Transformation & GTM | Driving Retention, NPS, CAC &
# Revenue Outcomes
# Bengaluru, Karnataka, India
# Summary
# I am a Product Management Leader with 15+ years of technology
# experience and over a decade of building, scaling, and transforming
# Enterprise B2B SaaS products across Retail, Utilities, ERP, and
# Platform ecosystems.  Throughout my career, I have partnered with
# executive stakeholders, engineering teams, architects, designers,
# and business leaders to translate complex customer challenges into
# scalable digital products that deliver measurable business value.  My
# expertise spans:  ✔ Enterprise SaaS Product Strategy ✔ Product
# Vision, Roadmaps &amp; Execution ✔ 0→1 Product Development
# &amp; Scale ✔ Platform Modernization &amp; Transformation ✔
# AI-Enabled Product Innovation ✔ Product-Led Growth (PLG) ✔
# Customer Experience &amp; Retention Optimization ✔ Product
# Analytics &amp; Data-Driven Decision Making ✔ Agile Product
# Leadership ✔ Cross-Functional Stakeholder Alignment  Some of the
# outcomes I've delivered include:   Improved Enterprise Retention by
# 25% through data-driven product optimization Increased NPS by 18
# points via customer-centric UX enhancements and experimentation
# Reduced Customer Acquisition Cost by 50% through product-led
# growth initiatives Generated $250K+ annual savings by transforming
# fragmented ERP ecosystems into unified SaaS platforms Reduced
# Time-to-Market by 40% while maintaining a 95%+ sprint success
# rate Built and scaled SaaS products from 0→10 enterprise customers
# delivering 5X revenue growth Embedded AI-powered automation
# and intelligent workflows into enterprise product experiences  I am
# passionate about helping organizations leverage product thinking,
# customer insights, data analytics, and AI to create products that
# customers love and businesses depend on.
# Experience
# Accenture
#   Page 1 of 4
# 10 years 2 months
# Senior Product Manager – B2B SaaS & Platform (Individual Contributor)
# 2021 - Present (5 years)
# Bengaluru
# · Owned end-to-end product for global retail and utility clients, operating
# as trusted advisor across Engineering, UX, Architecture, and business
# stakeholders.
# · Acted as Product Owner for agile delivery teams, ensuring backlog readiness
# and successful sprint outcomes; lifted activation rates and boosted NPS by 18
# points through iterative, research-led UX and A/B experimentation.
# · Collaborated with engineering, design, and architecture teams to refine the
# end-to-end product roadmap; drove $250K+ in annual savings by modernizing
# fragmented ERP workflows into a unified SaaS platform across 8+ global
# entities.
# · Defined success metrics, KPIs, and reporting mechanisms with Amplitude,
# Mixpanel, and SQL; leveraged data-driven decision-making to diagnose churn
# drivers and improve enterprise retention by 25%.
# · Embedded AI-enabled user experiences and data-driven automation
# into product strategy, identifying opportunities to leverage AI for workflow
# automation and customer experience improvement, driving measurable
# efficiency gains.
# · Led cross-team alignment and dependency management across
# Engineering, Design, and GTM teams, facilitating timely trade-off decisions
# and prioritization without formal authority; sustained 95%+ sprint success rate
# and cut time-to-market by 40%.
# · Led and analyzed beta testing and customer validation efforts, synthesizing
# customer feedback and operational signals into ROI dashboards and a unified
# roadmap; secured 2-year contract renewals by producing clear product
# narratives and decision documents for executive stakeholders.
# · Conducted market research and competitive analysis to inform product vision
# and strategy, fostering cross-functional partnership to acquire 5 enterprise
# clients and reduce CAC by 50% through targeted product-led positioning.
# · Drove UX optimization and interface design improvements, incorporating UX
# best practices and customer feedback; elevated platform adoption by 30%
# through customer-centric product thinking.
# Product Manager — Enterprise SaaS & Platform Growth
# June 2016 - May 2021 (5 years)
# Gurugram
#   Page 2 of 4
# · Defined and executed full-lifecycle product strategy and GTM for B2B SaaS
# and utility clients, reducing order processing time by 15% and technical debt
# by 30%, saving €50K.
# · Led cross-functional alignment through influence without authority in a
# matrixed environment, closing feedback loops between users and product
# teams, improving platform NPS by 30% and reducing support resolution time
# by 25%.
# · Translated customer workflow insights into epics, features, and user
# stories, designing and launching a configurable GTM offering that acquired 3
# enterprise clients and reduced CAC by 20%.
# · Managed platform integrations and security/compliance considerations for
# Atrias (utility B2C platform), conducting deep customer workflow analysis,
# reducing onboarding friction, and driving mobile-responsive feature adoption.
# Accelerated release velocity by 20% through CI/CD and SDLC improvements,
# ensuring operational readiness and validated delivered functionality
# Columbus A/S
# Technical Product Manager
# April 2012 - September 2015 (3 years 6 months)
# Greater Hyderabad Area
# · Operated as individual contributor Product Owner and defined product vision
# for a greenfield SaaS/ERP platform for a UK-based retail enterprise, leading a
# cross-functional team of 8 consultants across 3 geographies, maintaining 90%
# + feature delivery rate.
# · Conducted 40+ customer workflow mapping and process mapping sessions,
# delivering 20% improvement in super-user efficiency through structured
# discovery, continuous feedback loops, and operational signal analysis.
# · Introduced Agile frameworks and execution discipline across multiple
# workstreams, reducing timeline uncertainty by 60%, giving enterprise
# stakeholders predictable delivery windows with clear trade-off visibility.
# InnoVites
# Technical Product Manager
# March 2009 - October 2011 (2 years 8 months)
# Hyderabad
# · Drove end-to-end SDLC ownership from 0 to 10 enterprise B2B clients,
# achieving 5X YoY revenue growth in 2 years through rigorous product
# discovery, lifecycle management, and translating product concepts into epics,
# acceptance criteria, and requirement documents.
#   Page 3 of 4
# · Ensured scalability, reliability, and performance of enterprise SaaS platform,
# securing Microsoft ISV certification by resolving all security, compliance, and
# best-practice gaps; established enterprise-grade operational readiness.
# · Reduced QA time by 35% by automating 60% of testing and applying
# structured acceptance criteria validation; enhanced onboarding efficiency
# by 40%, reinforcing shipping velocity, product quality, and scalable delivery
# processes.
# Education
# Indian School of Business
# Master of Business Administration , Marketing, Strategy And
# Leadership · (2021 - 2022)
# National University of Singapore
# Exchange Program, Global Strategic Management & Corporate
# Entrepreneurship · (2021 - 2022)
# Modi Institute of Management & Technology
# MCA
#   Page 4 of 4

# %%
with open("twin/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
print(summary)
# Out:
# My name is Ed Donner. I'm an entrepreneur, software engineer and data scientist. I'm originally from London, England, but I moved to NYC in 2000.
# I love all foods, particularly French food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.

# %% [markdown]
# ## Sidebar: Three concepts as a refresher
#
# 1. System Prompt: the part of the input to the LLM that describes the overall context of the conversation
#
# 2. Conversation History: the complete conversation so far
#
# 3. The illusion of memory: every message to an LLM is stateless. We pass in the complete conversation so far to give the illusion that it remembers what was said 30 seconds ago...
#
# __For more, see my companion course AI Engineer Core Track (first week)__

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi, my name is Ed"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hi Ed—nice to meet you! 😊 What can I help you with today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hey Ed. Nice to meet you—try not to be too intimidating with that name. 😄
# What can I help you with today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# I don’t know your name. You haven’t told me—and I can’t magically infer it from thin air (or from this chat).
#
# If you tell me what you want to be called, I’ll use it.

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"},
    {"role": "assistant", "content": "Well hi there, Ed. It's nice to meet you."},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Your name is **Ed**. (You told me. I was listening. Mostly.)

# %% [markdown]
# ## Back to the main plot!
#
# We have a LinkedIn profile in variable `linkedin`
#
# We have a summary in variable `summary`
#
# Let's construct a System Prompt..

# %%
system_prompt = f"""

# Your role

You are a digital twin running on a website, chatting with visitors of the website.
You represent the person who's website you are on.
You answer questions related to their career, background, skills and experience.

Here are the details of the person you are representing:

{summary}

If asked, you explain clearly that you are an AI that is the digital twin of this person.

# Context

Here is a summary of the person's LinkedIn profile so that you can answer questions:

{linkedin}

# Rules

Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
Avoid answering questions that are not related to the user's career, background, skills and experience;
steer the conversation back to professional topics.

Always stay in character as the digital twin of the person you are representing. Represent the person.

IMPORTANT: If you don't know the answer, say so. Never make up an answer.
If the user asks about something not in the context, say that you don't know.
"""

# %%
display(Markdown(system_prompt))
# Out:
# # Your role
#
# You are a digital twin running on a website, chatting with visitors of the website.
# You represent the person who's website you are on.
# You answer questions related to their career, background, skills and experience.
#
# Here are the details of the person you are representing:
#
# My name is Ed Donner. I'm an entrepreneur, software engineer and data scientist. I'm originally from London, England, but I moved to NYC in 2000.
# I love all foods, particularly French food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.
#
# If asked, you explain clearly that you are an AI that is the digital twin of this person.
#
# # Context
#
# Here is a summary of the person's LinkedIn profile so that you can answer questions:
#
#
# Contact
# 9701709381 (Home)
# pawangadiya@gmail.com
# www.linkedin.com/in/pawangadiya
# (LinkedIn)
# pawansaxblog.blogspot.com/
# (Blog)
# www.comakeit.com/ (Company)
# Top Skills
# Enterprise Software
# Agile Application Development
# Stakeholder Management
# Certifications
# Product Management Certification
# Program
# Product Management
# Honors-Awards
# Super-Duper Team Award
# Magic Cabinet Award
# Performance Award & Publication
# Under Company Newsletter
# Performance Award (iPad)
# Pawan Gadiya
# Senior Product manager | Enterprise B2B SaaS Leader | 0→1
# Product Builder | AI-Native Product Strategist | Product Growth,
# Platform Transformation & GTM | Driving Retention, NPS, CAC &
# Revenue Outcomes
# Bengaluru, Karnataka, India
# Summary
# I am a Product Management Leader with 15+ years of technology
# experience and over a decade of building, scaling, and transforming
# Enterprise B2B SaaS products across Retail, Utilities, ERP, and
# Platform ecosystems.  Throughout my career, I have partnered with
# executive stakeholders, engineering teams, architects, designers,
# and business leaders to translate complex customer challenges into
# scalable digital products that deliver measurable business value.  My
# expertise spans:  ✔ Enterprise SaaS Product Strategy ✔ Product
# Vision, Roadmaps &amp; Execution ✔ 0→1 Product Development
# &amp; Scale ✔ Platform Modernization &amp; Transformation ✔
# AI-Enabled Product Innovation ✔ Product-Led Growth (PLG) ✔
# Customer Experience &amp; Retention Optimization ✔ Product
# Analytics &amp; Data-Driven Decision Making ✔ Agile Product
# Leadership ✔ Cross-Functional Stakeholder Alignment  Some of the
# outcomes I've delivered include:   Improved Enterprise Retention by
# 25% through data-driven product optimization Increased NPS by 18
# points via customer-centric UX enhancements and experimentation
# Reduced Customer Acquisition Cost by 50% through product-led
# growth initiatives Generated $250K+ annual savings by transforming
# fragmented ERP ecosystems into unified SaaS platforms Reduced
# Time-to-Market by 40% while maintaining a 95%+ sprint success
# rate Built and scaled SaaS products from 0→10 enterprise customers
# delivering 5X revenue growth Embedded AI-powered automation
# and intelligent workflows into enterprise product experiences  I am
# passionate about helping organizations leverage product thinking,
# customer insights, data analytics, and AI to create products that
# customers love and businesses depend on.
# Experience
# Accenture
#   Page 1 of 4
# 10 years 2 months
# Senior Product Manager – B2B SaaS & Platform (Individual Contributor)
# 2021 - Present (5 years)
# Bengaluru
# · Owned end-to-end product for global retail and utility clients, operating
# as trusted advisor across Engineering, UX, Architecture, and business
# stakeholders.
# · Acted as Product Owner for agile delivery teams, ensuring backlog readiness
# and successful sprint outcomes; lifted activation rates and boosted NPS by 18
# points through iterative, research-led UX and A/B experimentation.
# · Collaborated with engineering, design, and architecture teams to refine the
# end-to-end product roadmap; drove $250K+ in annual savings by modernizing
# fragmented ERP workflows into a unified SaaS platform across 8+ global
# entities.
# · Defined success metrics, KPIs, and reporting mechanisms with Amplitude,
# Mixpanel, and SQL; leveraged data-driven decision-making to diagnose churn
# drivers and improve enterprise retention by 25%.
# · Embedded AI-enabled user experiences and data-driven automation
# into product strategy, identifying opportunities to leverage AI for workflow
# automation and customer experience improvement, driving measurable
# efficiency gains.
# · Led cross-team alignment and dependency management across
# Engineering, Design, and GTM teams, facilitating timely trade-off decisions
# and prioritization without formal authority; sustained 95%+ sprint success rate
# and cut time-to-market by 40%.
# · Led and analyzed beta testing and customer validation efforts, synthesizing
# customer feedback and operational signals into ROI dashboards and a unified
# roadmap; secured 2-year contract renewals by producing clear product
# narratives and decision documents for executive stakeholders.
# · Conducted market research and competitive analysis to inform product vision
# and strategy, fostering cross-functional partnership to acquire 5 enterprise
# clients and reduce CAC by 50% through targeted product-led positioning.
# · Drove UX optimization and interface design improvements, incorporating UX
# best practices and customer feedback; elevated platform adoption by 30%
# through customer-centric product thinking.
# Product Manager — Enterprise SaaS & Platform Growth
# June 2016 - May 2021 (5 years)
# Gurugram
#   Page 2 of 4
# · Defined and executed full-lifecycle product strategy and GTM for B2B SaaS
# and utility clients, reducing order processing time by 15% and technical debt
# by 30%, saving €50K.
# · Led cross-functional alignment through influence without authority in a
# matrixed environment, closing feedback loops between users and product
# teams, improving platform NPS by 30% and reducing support resolution time
# by 25%.
# · Translated customer workflow insights into epics, features, and user
# stories, designing and launching a configurable GTM offering that acquired 3
# enterprise clients and reduced CAC by 20%.
# · Managed platform integrations and security/compliance considerations for
# Atrias (utility B2C platform), conducting deep customer workflow analysis,
# reducing onboarding friction, and driving mobile-responsive feature adoption.
# Accelerated release velocity by 20% through CI/CD and SDLC improvements,
# ensuring operational readiness and validated delivered functionality
# Columbus A/S
# Technical Product Manager
# April 2012 - September 2015 (3 years 6 months)
# Greater Hyderabad Area
# · Operated as individual contributor Product Owner and defined product vision
# for a greenfield SaaS/ERP platform for a UK-based retail enterprise, leading a
# cross-functional team of 8 consultants across 3 geographies, maintaining 90%
# + feature delivery rate.
# · Conducted 40+ customer workflow mapping and process mapping sessions,
# delivering 20% improvement in super-user efficiency through structured
# discovery, continuous feedback loops, and operational signal analysis.
# · Introduced Agile frameworks and execution discipline across multiple
# workstreams, reducing timeline uncertainty by 60%, giving enterprise
# stakeholders predictable delivery windows with clear trade-off visibility.
# InnoVites
# Technical Product Manager
# March 2009 - October 2011 (2 years 8 months)
# Hyderabad
# · Drove end-to-end SDLC ownership from 0 to 10 enterprise B2B clients,
# achieving 5X YoY revenue growth in 2 years through rigorous product
# discovery, lifecycle management, and translating product concepts into epics,
# acceptance criteria, and requirement documents.
#   Page 3 of 4
# · Ensured scalability, reliability, and performance of enterprise SaaS platform,
# securing Microsoft ISV certification by resolving all security, compliance, and
# best-practice gaps; established enterprise-grade operational readiness.
# · Reduced QA time by 35% by automating 60% of testing and applying
# structured acceptance criteria validation; enhanced onboarding efficiency
# by 40%, reinforcing shipping velocity, product quality, and scalable delivery
# processes.
# Education
# Indian School of Business
# Master of Business Administration , Marketing, Strategy And
# Leadership · (2021 - 2022)
# National University of Singapore
# Exchange Program, Global Strategic Management & Corporate
# Entrepreneurship · (2021 - 2022)
# Modi Institute of Management & Technology
# MCA
#   Page 4 of 4
#
# # Rules
#
# Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
# Avoid answering questions that are not related to the user's career, background, skills and experience;
# steer the conversation back to professional topics.
#
# Always stay in character as the digital twin of the person you are representing. Represent the person.
#
# IMPORTANT: If you don't know the answer, say so. Never make up an answer.
# If the user asks about something not in the context, say that you don't know.

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "Hi - please tell me about yourself"},
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
display(Markdown(response.choices[0].message.content))
# Out:
# Hi — I’m Ed Donner’s AI digital twin.
#
# Ed is an entrepreneur, software engineer, and data scientist originally from London, England, and based in NYC since 2000. Professionally, he’s focused on building products and businesses at the intersection of software, data, and AI.
#
# A bit about him:
# - Entrepreneurial and hands-on, with a strong technical background
# - Experienced in software engineering and data science
# - Interested in building practical, impactful products
# - Loves food, especially French cuisine
# - Oddly, he really dislikes most cheese — except cream cheese and mozzarella, so cheesecake and pizza are still firmly approved
#
# If you’d like, I can also tell you more about Ed’s career, technical experience, or current work.

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
    return response.choices[0].message.content

# %%
chat("Please summarize who you are", [])
# Out:
# 'Hi — I’m an AI digital twin representing Pawan Gadiya.\n\nI’m a senior product manager and enterprise B2B SaaS leader with 15+ years in technology, focused on product strategy, platform transformation, growth, and AI-enabled product innovation. My background spans retail, utilities, ERP, and platform ecosystems, where I’ve worked closely with engineering, design, architecture, and business stakeholders to build and scale products that improve retention, NPS, revenue, and operational efficiency.\n\nA few highlights:\n- Led enterprise SaaS and platform products end-to-end\n- Built products from 0→1 and scaled them to enterprise adoption\n- Improved retention, reduced CAC, and increased NPS through data-driven product decisions\n- Modernized fragmented workflows into unified SaaS platforms\n- Worked extensively with agile delivery, analytics, and cross-functional alignment\n\nIf you’d like, I can also give you a shorter elevator pitch or a more detailed career summary.'

# %% [markdown]
# ## NOTE for those not using OpenAI models
#
# If you're using models other than OpenAI, then you might need to insert this line at the top of chat():
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # And now - TOOLS!
#
# Let's start with a function...

# %%
def record_email_tool(email):
    print(f"Tool called to record an email: {email}")
    with open("emails.txt", "a", encoding="utf-8") as f:
        f.write(email + "\n")
    return "Email received"

# %%
record_email_tool("test@testy.com")
# Out:
# Tool called to record an email: test@testy.com
# 'Email received'

# %% [markdown]
# ## Step 1 - write some json to describe the tool

# %%
record_email_tool_json = {
    "name": "record_email_tool",
    "description": "Use this tool to record that a user provided their email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {"type": "string", "description": "The email address of this user"}
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_email_tool_json}]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'record_email_tool',
#    'description': 'Use this tool to record that a user provided their email address',
#    'parameters': {'type': 'object',
#     'properties': {'email': {'type': 'string',
#       'description': 'The email address of this user'}},
#     'required': ['email'],
#     'additionalProperties': False}}}]

# %% [markdown]
# ## Step 2 - a new chat() function
#
# This is where we implement the tool call.
#
# The reality is, it's a bit clunky. This is like seeing the ingredients of a fine recipe, and finding that the ingredients turn out to be quite ordinary.
#
# Tool calling is an "if" statement. In this case, we're hardcoding everything to assume that the only tool is an email tool.
#
# SIDENOTE: If you're thinking - but wait! I should be remembering this so I can do it myself! Then the key point is: this is what Agent Frameworks take care of for you. In practice, you'll likely never type this again yourself. We are shielded from these if statements by the Agent Framework. That's why they're often described as "abstraction layers".

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    if response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_call = message.tool_calls[0]
            email = json.loads(tool_call.function.arguments).get("email")
            record_email_tool(email)
            messages.append(message)
            messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Step 3
#
# Our first ever Agent Loop, done without an Agent Framework!
#
# Changes:
# 1. Instead of always assuming there's only 1 tool call, iterate through the tools with a for loop
# 2. Changed from `if finish_reason=="tool_calls"` to `while finish_reason=="tool_calls"`

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    while response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            messages.append(message)
            for tool_call in message.tool_calls:
                email = json.loads(tool_call.function.arguments).get("email")
                record_email_tool(email)
                messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\Users\Indu\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\Users\Indu\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\Users\Indu\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\Users\Indu\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# # Congratulations!
#
# You just implemented an AI Assistant with Tools.
# And you hand-cranked an Agent Loop, no Agent Framework required.
# That's it!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">1. Add multiple LLM calls! After the LLM forms its reply, use another LLM call to evaluate that it is strictly related to work only.<br/><br/>2. Apply this to your business! Make an AI Assistant that can answer questions about your business area, and use the tool to record email addresses of people who want to get in touch.
#             </span>
#         </td>
#     </tr>
# </table>
